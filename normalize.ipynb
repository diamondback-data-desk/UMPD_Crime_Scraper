# %% [markdown]
# ## Import statements

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import folium
import time

# %%
crime_export_df = pd.read_csv("UMPD_crime_export_1_2017_to_11_2024.csv")
crime_export_df = crime_export_df[crime_export_df["case_number"].str[:4] == "2024"]

for index,row in crime_export_df.iterrows():
    location_desc = f"{row["location_desc"]}, COLLEGE PARK, MARYLAND"
    row["location_desc"] = location_desc
    crime_export_df.loc[index] = row
    
crime_export_df
# Out:
#        Unnamed: 0    case_number date_occurred time_occurred  \
# 11095           0  2024-00000014      01/01/24         00:18
# 11096           2  2024-00000081      01/01/24         02:43
# 11097           4  2024-00000092      01/01/24         02:45
# 11098           6  2024-00000096      01/01/24         03:09
# 11099           8  2024-00000463      12/20/23         14:00
# ...           ...            ...           ...           ...
# 12922         148  2024-00200197      11/14/24         00:56
# 12923         150  2024-00200763      11/14/24         13:50
# 12924         152  2024-00200781      11/14/24         15:00
# 12925         154  2024-00201124      11/15/24         00:14
# 12926         156  2024-00201235      11/15/24         02:16
#
#                                            location_desc date_reported  \
# 11095  8700 block of Baltimore Ave, COLLEGE PARK, MAR...      01/01/24
# 11096                    Knox Rd, COLLEGE PARK, MARYLAND      01/01/24
# ...

# %%
crime_analysis_df = crime_export_df[["case_number","date_reported","time_reported","type","disposition"]]
crime_analysis_df
# Out:
#          case_number date_reported time_reported  \
# 11095  2024-00000014      01/01/24         00:18
# 11096  2024-00000081      01/01/24         02:43
# 11097  2024-00000092      01/01/24         02:56
# 11098  2024-00000096      01/01/24         03:09
# 11099  2024-00000463      01/01/24         16:15
# ...              ...           ...           ...
# 12922  2024-00200197      11/14/24         00:56
# 12923  2024-00200763      11/14/24         13:57
# 12924  2024-00200781      11/14/24         15:45
# 12925  2024-00201124      11/15/24         00:14
# 12926  2024-00201235      11/15/24         02:16
#
#                                            type     disposition
# 11095                 Recovered Stolen Property          Arrest
# 11096                       Injured/Sick Person             CBE
# 11097                       Injured/Sick Person             CBE
# 11098                                   DWI/DUI          Arrest
# ...

# %%
crime_export_df["norm_loc_desc"] = None
crime_export_df["latitute"] = None
crime_export_df["longitude"] = None

for index,row in crime_export_df.iterrows():
    geolocator = Nominatim(user_agent="UMPD_Location_Normalizer")
    location = geolocator.geocode(row["location_desc"])
    print(location)
    if location:
        row["norm_loc_desc"] = location
        row["latitude"] = location.latitude
        row["latitude"] = location.longitude
        crime_export_df.loc[index] = row
        time.sleep(1)
    
crime_export_df
# Out:
# None
# Knox Road, Lord Calvert Manor, Old Town, College Park, Prince George's County, Maryland, 20740, United States
# Knox Road, Lord Calvert Manor, Old Town, College Park, Prince George's County, Maryland, 20740, United States
# None
# None
# None
# None
# None
# None
# Baltimore Avenue, Lakeland, College Park, Prince George's County, Maryland, 20742, United States
# Greenbelt Road, Oak Springs, Branchville, College Park, Prince George's County, Maryland, 20740, United States
# None
# None
# None
# None
# None
# None
# None
# None
# None
# Baltimore Avenue, Lakeland, College Park, Prince George's County, Maryland, 20742, United States
# None
# None
# None
# None
# Baltimore Avenue, Lakeland, College Park, Prince George's County, Maryland, 20742, United States
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ...
